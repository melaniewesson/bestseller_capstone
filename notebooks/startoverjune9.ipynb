# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import time
from bs4 import BeautifulSoup

# %%
goodreads_clean = pd.read_csv(r"C:\Users\melan\Documents\DA8\Projects\bestseller_capstone\data\clean_goodreads.csv")

# %%
goodreads_clean.head(20)
# Out:
#     Unnamed: 0           isbn  \
# 0            0  9780440337973
# 1            1  9780385541206
# 2            2  9781101984772
# 3            3  9780345544964
# 4            4  9781476738031
# 5            5  9780425285350
# 6            6  9780698193000
# 7            7  9781455586493
# 8            8  9780399574184
# 9            9  9780316407168
# 10          10  9781250105615
# 11          11  9781429960274
# 12          12  9780385538923
# 13          13  9780345459503
# 14          14  9781627795951
# 15          15  9780698156357
# 16          16  9780997263640
# 17          17  9780547345666
# 18          18  9780061752728
# 19          19  9781942833291
#
#                                                 title            author  \
# 0   The Guernsey Literary and Potato Peel Pie Society  Mary Ann Shaffer
# 1                                        The Whistler      John Grisham
# 2                                        Ring of Fire       Brad Taylor
# 3                                  Small Great Things      Jodi Picoult
# 4                                    A Man Called Ove   Fredrik Backman
# 5                                        The Mistress    Danielle Steel
# 6                         The Guests on South Battery     Karen   White
# 7                                       No Man's Land    David Baldacci
# 8                                      Below the Belt      Stuart Woods
# 9                                      Cross the Line   James Patterson
# 10                                            The Dry       Jane Harper
# 11                                    A Dog's Purpose  W. Bruce Cameron
# 12                                    The Sleepwalker   Chris Bohjalian
# 13                                     Distant Shores    Kristin Hannah
# 14                                    The North Water       Ian McGuire
# 15                                         Silver Bay        Jojo Moyes
# 16                                 Commander in Chief        Katy Evans
# 17                                The Handmaid's Tale   Margaret Atwood
# 18                                      State of Fear  Michael Crichton
# 19                                   Separation Games        C.D. Reiss
#
#     avg_rating  count_rating  count_reviews date_published  \
# 0         4.19      721465.0        60356.0     2008-07-29
# 1         3.95      120472.0         7710.0     2016-10-25
# 2         4.28        4371.0          230.0     2017-01-10
# 3         4.35      342790.0        30250.0     2016-10-11
# 4         4.38      917052.0        98756.0     2012-08-27
# 5         3.89       11239.0          680.0     2017-01-03
# 6         4.13       10032.0          949.0     2017-01-10
# 7         4.20       44963.0         2474.0     2016-11-15
# 8         4.01        6351.0          435.0     2017-01-03
# 9         4.08       24059.0         1354.0     2016-11-16
# 10        4.06      219993.0        18379.0     2016-05-31
# 11        4.35      127947.0        14287.0     2010-07-01
# 12        3.68       20091.0         2656.0     2017-01-10
# 13        3.76       41550.0         2399.0     2002-01-01
# 14        3.99       30122.0         3619.0     2016-02-11
# 15        3.77       28487.0         2034.0     2007-01-10
# 16        3.86       11900.0         1340.0     2017-01-05
# 17        4.13     1899669.0        89493.0     1985-01-01
# 18        3.70       85167.0         3597.0     2004-12-07
# 19        4.17        5214.0          695.0     2017-01-03
#
#                                             top_genre              genre1  \
# 0   Historical Fiction, Fiction, Romance, Historic...  Historical Fiction
# 1   Fiction, Mystery, Thriller, Audiobook, Crime, ...             Fiction
# 2   Thriller, Fiction, Action, Military Fiction, S...            Thriller
# 3   Fiction, Contemporary, Audiobook, Adult, Adult...             Fiction
# 4   Fiction, Contemporary, Audiobook, Humor, Adult...             Fiction
# 5   Romance, Fiction, Chick Lit, Adult, Contempora...             Romance
# 6   Mystery, Fiction, Paranormal, Ghosts, Romance,...             Mystery
# 7   Fiction, Thriller, Mystery, Crime, Audiobook, ...             Fiction
# 8   Mystery, Fiction, Thriller, Crime, Suspense, A...             Mystery
# 9   Mystery, Fiction, Thriller, Crime, Mystery Thr...             Mystery
# 10  Mystery, Fiction, Thriller, Crime, Mystery Thr...             Mystery
# 11  Fiction, Animals, Dogs, Contemporary, Fantasy,...             Fiction
# 12  Fiction, Mystery, Thriller, Suspense, Audioboo...             Fiction
# 13  Fiction, Chick Lit, Romance, Contemporary, Dra...             Fiction
# 14  Historical Fiction, Fiction, Thriller, Histori...  Historical Fiction
# 15  Fiction, Romance, Chick Lit, Contemporary, Aud...             Fiction
# 16  Romance, Contemporary Romance, Contemporary, P...             Romance
# 17  Fiction, Classics, Dystopia, Science Fiction, ...             Fiction
# 18  Fiction, Thriller, Science Fiction, Mystery, S...             Fiction
# 19  BDSM, Romance, Erotica, Contemporary Romance, ...                BDSM
#
#                   genre2           genre3
# 0                Fiction          Romance
# 1                Mystery         Thriller
# 2                Fiction           Action
# 3           Contemporary        Audiobook
# 4           Contemporary        Audiobook
# 5                Fiction        Chick Lit
# 6                Fiction       Paranormal
# 7               Thriller          Mystery
# 8                Fiction         Thriller
# 9                Fiction         Thriller
# 10               Fiction         Thriller
# 11               Animals             Dogs
# 12               Mystery         Thriller
# 13             Chick Lit          Romance
# 14               Fiction         Thriller
# 15               Romance        Chick Lit
# 16  Contemporary Romance     Contemporary
# 17              Classics         Dystopia
# 18              Thriller  Science Fiction
# 19               Romance          Erotica

# %%
len(goodreads_clean)
# Out:
# 6828

# %%
null_title_rows = goodreads_clean[goodreads_clean['title'].isnull()]
len(null_title_rows)
# Out:
# 179

# %%
null_title_rows.nunique()
null_title_rows = null_title_rows.drop('Unnamed: 0', axis=1)

# %%
unique_nulls = null_title_rows.drop_duplicates()
len(unique_nulls)
# Out:
# 161

# %%
unique_nulls.to_csv(r"C:\Users\melan\Documents\DA8\Projects\bestseller_capstone\data\unique_goodreads_nulls.csv")

# %%
len(goodreads_clean)
# Out:
# 6828

# %%
# Remove null values
goodreads_clean = goodreads_clean.dropna()

# Remove duplicates
goodreads_clean = goodreads_clean.drop_duplicates()

# Display the updated dataframe
len(goodreads_clean)
# Out:
# 6578

# %%
goodreads_clean.to_csv(r"C:\Users\melan\Documents\DA8\Projects\bestseller_capstone\data\goodreads_read_to_merge.csv")

# %%
nyt = pd.read_csv(r"C:\Users\melan\Documents\DA8\Projects\bestseller_capstone\data\merged_dataframe.csv")

# %%
nyt.head()
# Out:
#                                                title  \
# 0                                       FULL PACKAGE
# 1  THE GUERNSEY LITERARY AND POTATO PEEL PIE SOCIETY
# 2                                       THE WHISTLER
# 3                                       RING OF FIRE
# 4                                 SMALL GREAT THINGS
#
#                                          description  \
# 0  A man shares a cramped apartment with his frie...
# 1  After World War II, a journalist travels to th...
# 2  A whistleblower alerts a Florida investigator ...
# 3  Pike Logan, a member of a secret counterterror...
# 4  A medical crisis entangles a black nurse, a wh...
#
#                              contributor                              author  \
# 0                      by Lauren Blakely                      Lauren Blakely
# 1  by Mary Ann Shaffer and Annie Barrows  Mary Ann Shaffer and Annie Barrows
# 2                        by John Grisham                        John Grisham
# 3                         by Brad Taylor                         Brad Taylor
# 4                        by Jodi Picoult                        Jodi Picoult
#
#   contributor_note  price  age_group       publisher primary_isbn13  \
# 0              NaN    0.0        NaN  Lauren Blakely  A00B01MT5HMRV
# 1              NaN    0.0        NaN            Dial  9780440337973
# 2              NaN    0.0        NaN       Doubleday  9780385541206
# 3              NaN    0.0        NaN          Dutton  9781101984772
# 4              NaN    0.0        NaN      Ballantine  9780345544964
#
#   primary_isbn10  rank  rank_last_week  weeks_on_list  asterisk  dagger  \
# 0           None     1               0              1         0       0
# 1     0440337976     2               0              2         0       0
# 2     0385541201     3               4             12         0       0
# 3           None     4               0              1         0       0
# 4     034554496X     5               7              9         0       0
#
#          week        nyt_list                       file month
# 0  2017-01-25  E-Book Fiction  2012to2017_e_book_fiction   NaN
# 1  2017-01-25  E-Book Fiction  2012to2017_e_book_fiction   NaN
# 2  2017-01-25  E-Book Fiction  2012to2017_e_book_fiction   NaN
# 3  2017-01-25  E-Book Fiction  2012to2017_e_book_fiction   NaN
# 4  2017-01-25  E-Book Fiction  2012to2017_e_book_fiction   NaN

# %%
len(nyt)
# Out:
# 32216

# %%
# Convert data types to strings
nyt['primary_isbn13'] = nyt['primary_isbn13'].astype(str)
goodreads_clean['isbn'] = goodreads_clean['isbn'].astype(str)

# Merge the dataframes
merged_df = pd.merge(nyt, goodreads_clean, left_on='primary_isbn13', right_on='isbn', how='left')

# Display the merged dataframe
len(merged_df)
# Out:
# 38194

# %%
len(merged_df)
# Out:
# 38194

# %%
merged_df.head()
# Out:
#                                              title_x  \
# 0                                       FULL PACKAGE
# 1  THE GUERNSEY LITERARY AND POTATO PEEL PIE SOCIETY
# 2                                       THE WHISTLER
# 3                                       RING OF FIRE
# 4                                 SMALL GREAT THINGS
#
#                                          description  \
# 0  A man shares a cramped apartment with his frie...
# 1  After World War II, a journalist travels to th...
# 2  A whistleblower alerts a Florida investigator ...
# 3  Pike Logan, a member of a secret counterterror...
# 4  A medical crisis entangles a black nurse, a wh...
#
#                              contributor                            author_x  \
# 0                      by Lauren Blakely                      Lauren Blakely
# 1  by Mary Ann Shaffer and Annie Barrows  Mary Ann Shaffer and Annie Barrows
# 2                        by John Grisham                        John Grisham
# 3                         by Brad Taylor                         Brad Taylor
# 4                        by Jodi Picoult                        Jodi Picoult
#
#   contributor_note  price  age_group       publisher primary_isbn13  \
# 0              NaN    0.0        NaN  Lauren Blakely  A00B01MT5HMRV
# 1              NaN    0.0        NaN            Dial  9780440337973
# 2              NaN    0.0        NaN       Doubleday  9780385541206
# 3              NaN    0.0        NaN          Dutton  9781101984772
# 4              NaN    0.0        NaN      Ballantine  9780345544964
#
#   primary_isbn10  ...                                            title_y  \
# 0           None  ...                                                NaN
# 1     0440337976  ...  The Guernsey Literary and Potato Peel Pie Society
# 2     0385541201  ...                                       The Whistler
# 3           None  ...                                       Ring of Fire
# 4     034554496X  ...                                 Small Great Things
#
#            author_y  avg_rating  count_rating  count_reviews date_published  \
# 0               NaN         NaN           NaN            NaN            NaN
# 1  Mary Ann Shaffer        4.19      721465.0        60356.0     2008-07-29
# 2      John Grisham        3.95      120472.0         7710.0     2016-10-25
# 3       Brad Taylor        4.28        4371.0          230.0     2017-01-10
# 4      Jodi Picoult        4.35      342790.0        30250.0     2016-10-11
#
#                                            top_genre              genre1  \
# 0                                                NaN                 NaN
# 1  Historical Fiction, Fiction, Romance, Historic...  Historical Fiction
# 2  Fiction, Mystery, Thriller, Audiobook, Crime, ...             Fiction
# 3  Thriller, Fiction, Action, Military Fiction, S...            Thriller
# 4  Fiction, Contemporary, Audiobook, Adult, Adult...             Fiction
#
#          genre2     genre3
# 0           NaN        NaN
# 1       Fiction    Romance
# 2       Mystery   Thriller
# 3       Fiction     Action
# 4  Contemporary  Audiobook
#
# [5 rows x 31 columns]
