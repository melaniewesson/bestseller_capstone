# %%
import pandas as pd
import numpy as np

# %%
goodreads = pd.read_csv(r"C:\Users\melan\Documents\DA8\Projects\capstone\data\clean_goodreads.csv")

# %%
goodreads.head()
# Out:
#             isbn                                              title  \
# 0  9780440337973  The Guernsey Literary and Potato Peel Pie Society
# 1  9780385541206                                       The Whistler
# 2  9781101984772                                       Ring of Fire
# 3  9780345544964                                 Small Great Things
# 4  9781476738031                                   A Man Called Ove
#
#              author  avg_rating  count_rating  count_reviews  \
# 0  Mary Ann Shaffer        4.19      721465.0        60356.0
# 1      John Grisham        3.95      120472.0         7710.0
# 2       Brad Taylor        4.28        4371.0          230.0
# 3      Jodi Picoult        4.35      342790.0        30250.0
# 4   Fredrik Backman        4.38      917052.0        98756.0
#
#                      date_published  \
# 0     First published July 29, 2008
# 1  First published October 25, 2016
# 2  First published January 10, 2017
# ...

# %%
goodreads.tail()
# Out:
#                isbn                                title           author  \
# 6823  9781538731604                   The 18th Abduction  James Patterson
# 6824  9781420149869                              Envious     Lisa Jackson
# 6825  9780525536604                            Neon Prey    John Sandford
# 6826  9781335979957  Denim and Diamonds/A Military Match  Debbie Macomber
# 6827  9780399181351                                  NaN              NaN
#
#       avg_rating  count_rating  count_reviews                  date_published  \
# 6823        4.10       29983.0         1956.0  First published April 29, 2019
# 6824        3.98        2554.0          147.0  First published March 31, 2020
# 6825        4.18       21056.0         1592.0  First published April 23, 2019
# 6826        3.98          85.0            6.0        Published March 24, 2020
# 6827         NaN           NaN            NaN                             NaN
#
# ...

# %%
goodreads.dtypes
# Out:
# isbn                int64
# title              object
# author             object
# avg_rating        float64
# count_rating      float64
# count_reviews     float64
# date_published     object
# top_genre          object
# dtype: object

# %%
goodreads.isnull().sum()
# Out:
# isbn                0
# title             179
# author            179
# avg_rating        179
# count_rating      179
# count_reviews     179
# date_published    179
# top_genre         193
# dtype: int64

# %%
#delete nulls (will add with self-published df)
goodreads = goodreads.dropna(subset=['title'])

# %%
self_published = pd.read_csv(r"C:\Users\melan\Documents\DA8\Projects\capstone\data\self_published.csv")

# %%
#combine dfs
all_goodreads = pd.concat([goodreads, self_published])

# %%
#fix date_published column format
#Remove 'first published' and 'published'

goodreads['date_published'] = goodreads['date_published'].str.replace('First published ', '').str.replace('Published ', '')
goodreads.head()
# Out:
#             isbn                                              title  \
# 0  9780440337973  The Guernsey Literary and Potato Peel Pie Society
# 1  9780385541206                                       The Whistler
# 2  9781101984772                                       Ring of Fire
# 3  9780345544964                                 Small Great Things
# 4  9781476738031                                   A Man Called Ove
#
#              author  avg_rating  count_rating  count_reviews  \
# 0  Mary Ann Shaffer        4.19      721465.0        60356.0
# 1      John Grisham        3.95      120472.0         7710.0
# 2       Brad Taylor        4.28        4371.0          230.0
# 3      Jodi Picoult        4.35      342790.0        30250.0
# 4   Fredrik Backman        4.38      917052.0        98756.0
#
#      date_published                                          top_genre
# 0     July 29, 2008  Genres, Historical Fiction, Fiction, Romance, ...
# ...

# %%
#convert to datetime format
goodreads['date_published'] = pd.to_datetime(goodreads['date_published'], errors='coerce')
goodreads.head()
# Out:
#             isbn                                              title  \
# 0  9780440337973  The Guernsey Literary and Potato Peel Pie Society
# 1  9780385541206                                       The Whistler
# 2  9781101984772                                       Ring of Fire
# 3  9780345544964                                 Small Great Things
# 4  9781476738031                                   A Man Called Ove
#
#              author  avg_rating  count_rating  count_reviews date_published  \
# 0  Mary Ann Shaffer        4.19      721465.0        60356.0     2008-07-29
# 1      John Grisham        3.95      120472.0         7710.0     2016-10-25
# 2       Brad Taylor        4.28        4371.0          230.0     2017-01-10
# 3      Jodi Picoult        4.35      342790.0        30250.0     2016-10-11
# 4   Fredrik Backman        4.38      917052.0        98756.0     2012-08-27
#
#                                            top_genre
# ...

# %%
goodreads[goodreads['date_published'] == 'NaT'].sum()
# Out:
# C:\Users\melan\AppData\Local\Temp\ipykernel_5748\4070747663.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   goodreads[goodreads['date_published'] == 'NaT'].sum()
# isbn             0.0
# title            0.0
# author           0.0
# avg_rating       0.0
# count_rating     0.0
# count_reviews    0.0
# top_genre        0.0
# dtype: float64

# %%
#Next need to fix genre column
goodreads['top_genre'][0]
# Out:
# 'Genres, Historical Fiction, Fiction, Romance, Historical, World War II, Book Club, War'

# %%
#Remove 'Genres ' part
goodreads['top_genre'] = goodreads['top_genre'].str.replace('Genres, ', '')
goodreads.head()
# Out:
#             isbn                                              title  \
# 0  9780440337973  The Guernsey Literary and Potato Peel Pie Society
# 1  9780385541206                                       The Whistler
# 2  9781101984772                                       Ring of Fire
# 3  9780345544964                                 Small Great Things
# 4  9781476738031                                   A Man Called Ove
#
#              author  avg_rating  count_rating  count_reviews date_published  \
# 0  Mary Ann Shaffer        4.19      721465.0        60356.0     2008-07-29
# 1      John Grisham        3.95      120472.0         7710.0     2016-10-25
# 2       Brad Taylor        4.28        4371.0          230.0     2017-01-10
# 3      Jodi Picoult        4.35      342790.0        30250.0     2016-10-11
# 4   Fredrik Backman        4.38      917052.0        98756.0     2012-08-27
#
#                                            top_genre
# ...

# %%
#Split column into list of genres
genre_list = goodreads['top_genre'].str.split(', ')

# %%
goodreads['genre1'] = genre_list.str[0]
goodreads['genre2'] = genre_list.str[1]
goodreads['genre3'] = genre_list.str[2]

# %%
goodreads.head()
# Out:
#             isbn                                              title  \
# 0  9780440337973  The Guernsey Literary and Potato Peel Pie Society
# 1  9780385541206                                       The Whistler
# 2  9781101984772                                       Ring of Fire
# 3  9780345544964                                 Small Great Things
# 4  9781476738031                                   A Man Called Ove
#
#              author  avg_rating  count_rating  count_reviews date_published  \
# 0  Mary Ann Shaffer        4.19      721465.0        60356.0     2008-07-29
# 1      John Grisham        3.95      120472.0         7710.0     2016-10-25
# 2       Brad Taylor        4.28        4371.0          230.0     2017-01-10
# 3      Jodi Picoult        4.35      342790.0        30250.0     2016-10-11
# 4   Fredrik Backman        4.38      917052.0        98756.0     2012-08-27
#
#                                            top_genre              genre1  \
# ...

# %%
len(goodreads)
# Out:
# 6828
